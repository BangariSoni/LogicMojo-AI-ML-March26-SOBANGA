# %%
print("Hello")
# Out:
# Hello

# %%
a=10
b=9 + 11j
print(a+b)
# Out:
# (19+11j)

# %%
text="Artificial"
print(text[6:9])
print(text[6:8])
# Out:
# cia
# ci

# %%
premium = 20000
claim = 15000

print(premium > claim)
print(premium < claim)
print(premium == claim)
# Out:
# True
# False
# False

# %%
risk = premium > claim
print(risk)
# Out:
# True

# %%
company = "Chubb Insurance"

print(company[0])
print(company[3])
print(company[-1])
# Out:
# C
# b
# e

# %%
print(company[0:5])
print(company[6:15])
# Out:
# Chubb
# Insurance

# %%
print(company[::-1])
# Out:
# ecnarusnI bbuhC

# %%
text = "chubb insurance"

print(text.upper())
print(text.capitalize())
print(text.replace("insurance","AI"))
print(len(text))
# Out:
# CHUBB INSURANCE
# Chubb insurance
# chubb AI
# 15

# %%
sentence = "I want to become AI engineer"
print(sentence.split())
# Out:
# ['I', 'want', 'to', 'become', 'AI', 'engineer']

# %%
policy_holder = "Soni"
premium = 25000
claim = 18000

profit = premium - claim

print(f"Policy Holder: {policy_holder}")
print(f"Premium: {premium}")
print(f"Claim: {claim}")
print(f"Profit: {profit}")
# Out:
# Policy Holder: Soni
# Premium: 25000
# Claim: 18000
# Profit: 7000

# %%
if claim > premium:
    print("Company Loss")
else:
    print("Company Profit")
# Out:
# Company Profit

# %%
premium = 20000
claim = 15000
claim_ratio = claim / premium

print("claim ration",claim_ratio)

if(claim_ratio>0.7):
    print("High Risk")
elif(claim_ratio>0.4):
    print("Medium Risjk")
else:
    print("Low Risk")
# Out:
# claim ration 0.75
# High Risk
